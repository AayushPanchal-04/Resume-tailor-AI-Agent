# %%
import os

# %%
os.chdir(r"C:\Users\AKS\Tailored Resume AI Project")

# %%
api_key = "you_api_key_here"

# %%
with open('.env', 'w', encoding='utf-8') as f:
    f.write(f'OPENAI_API_KEY={api_key}\n')

# %%
print(" .env file created!")
print(f" Location: {os.getcwd()}\\.env")
# Out:
# ✅ .env file created!
# 📁 Location: C:\Users\AKS\Tailored Resume AI Project\.env

# %%
# !pip install langchain-core
# Out:
# Requirement already satisfied: langchain-core in c:\users\aks\anaconda3\lib\site-packages (1.1.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\aks\anaconda3\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\aks\anaconda3\lib\site-packages (from langchain-core) (0.4.56)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\aks\anaconda3\lib\site-packages (from langchain-core) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\aks\anaconda3\lib\site-packages (from langchain-core) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\aks\anaconda3\lib\site-packages (from langchain-core) (6.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\aks\anaconda3\lib\site-packages (from langchain-core) (8.2.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\aks\anaconda3\lib\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\aks\anaconda3\lib\site-packages (from langchain-core) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\aks\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\aks\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\aks\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\aks\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\aks\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.32.3)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\aks\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\aks\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\aks\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\aks\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.4.2)
# Requirement already satisfied: anyio in c:\users\aks\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (4.11.0)
# Requirement already satisfied: certifi in c:\users\aks\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in c:\users\aks\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.9)
# Requirement already satisfied: idna in c:\users\aks\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4)
# Requirement already satisfied: h11>=0.16 in c:\users\aks\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (0.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aks\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aks\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.26.16)
# Requirement already satisfied: sniffio>=1.1 in c:\users\aks\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.3.1)

# %%
from dotenv import load_dotenv
import os

# Load the .env file
load_dotenv()

# Get the API key
api_key = os.getenv("OPENAI_API_KEY")

if api_key:
    print("✅ API Key loaded successfully!")
else:
    print("❌ API Key not found!")
# Out:
# ✅ API Key loaded successfully!
#    Key starts with: sk-proj-uO6AmDo...

# %%
# !streamlit run resume.py
